# %%
s

# %%
# Crea el dataset con tus datos obtenidos en barplot_data.txt
frecuencias = [2, 1, 3, 1, 153, 42, 1, 21, 37, 5258, 1, 43, 5346, 85, 106]

len(frecuencias) # todo bien!
# Out:
# 15

# %%
# Cambia el nombre de las categorías por las que obtuviste no lo dejes como "Categoría A", etc.
categorias = ['ncRNA', 'SRP_RNA', 'sequence_feature', 'tmRNA', 'exon', 'rRNA',
              'region', 'CDS', 'riboswitch', 'Homology', 'RNase_P_RNA',
              'binding_site', 'gene', 'pseudogene', 'tRNA']
categorias = [ ''.join(wrap(l, 11)) for l in categorias]

y_pos = np.arange(len(categorias))

# %%
# Gráfico de barras
plt.figure(figsize=(25, 10), dpi=80)
plt.bar(y_pos, frecuencias)

# Nombres en el eje-x
plt.xticks(y_pos, categorias)

# Mostrar la gráfica
#plt.show()

#guardar
plt.savefig('barplot.png')
